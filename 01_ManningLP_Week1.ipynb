# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt
# %matplotlib inline
os.chdir("/content/drive/My Drive/Colab Notebooks/Datasets/hh/t1")
image_t1 = nib.load("IXI012-HH-1211-T1_fcm.nii.gz")
image_data_t1 = image_t1.get_fdata()
image_data_t1.shape
# Out:
# (240, 240, 180)

# %%
plt.imshow(image_data_t1[201,:,:])

# %%
os.chdir("/content/drive/My Drive/Colab Notebooks/Datasets/hh/t2")
image_t2 = nib.load("IXI012-HH-1211-T2_reg_fcm.nii.gz")
image_data_t2 = image_t2.get_fdata()

# %%
plt.imshow(image_data_t2[201,:,:])
